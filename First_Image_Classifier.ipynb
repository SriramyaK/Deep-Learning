# %% [markdown]
# <a href="https://colab.research.google.com/github/SriramyaK/Deep-Learning/blob/master/First_Image_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if it doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/content/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/content/data/oxford-iiit-pet/images'),
#  PosixPath('/content/data/oxford-iiit-pet/annotations')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/content/data/oxford-iiit-pet/images/pug_8.jpg'),
#  PosixPath('/content/data/oxford-iiit-pet/images/miniature_pinscher_155.jpg'),
#  PosixPath('/content/data/oxford-iiit-pet/images/beagle_185.jpg'),
#  PosixPath('/content/data/oxford-iiit-pet/images/english_cocker_spaniel_173.jpg'),
#  PosixPath('/content/data/oxford-iiit-pet/images/Siamese_17.jpg')]

# %%
np.random.seed(2)
pat=r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat,ds_tfms=get_transforms(), size=224)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# pug,miniature_pinscher,beagle,leonberger,pug
# Path: /content/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Bengal,samoyed,Birman,newfoundland,english_setter
# Path: /content/data/oxford-iiit-pet/images;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.396319</td>
#       <td>0.339245</td>
#       <td>0.107578</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.556144</td>
#       <td>0.238300</td>
#       <td>0.080514</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.352668</td>
#       <td>0.210901</td>
#       <td>0.067659</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.257028</td>
#       <td>0.207687</td>
#       <td>0.070365</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Birman', 'Ragdoll', 7),
#  ('Ragdoll', 'Birman', 6),
#  ('Russian_Blue', 'British_Shorthair', 6),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('Egyptian_Mau', 'Bengal', 4),
#  ('chihuahua', 'miniature_pinscher', 4),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('Maine_Coon', 'Bengal', 3),
#  ('Maine_Coon', 'Ragdoll', 3),
#  ('american_pit_bull_terrier', 'american_bulldog', 3),
#  ('basset_hound', 'beagle', 3),
#  ('Maine_Coon', 'Persian', 2),
#  ('Russian_Blue', 'Abyssinian', 2),
#  ('Russian_Blue', 'Bombay', 2),
#  ('Siamese', 'Birman', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('american_bulldog', 'staffordshire_bull_terrier', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2),
#  ('yorkshire_terrier', 'havanese', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.539296</td>
#       <td>0.331178</td>
#       <td>0.100135</td>
#       <td>01:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# pug,miniature_pinscher,beagle,leonberger,pug
# Path: /content/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Bengal,samoyed,Birman,newfoundland,english_setter
# Path: /content/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2,max_lr=slice(1e-06,1e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.238504</td>
#       <td>0.195885</td>
#       <td>0.059540</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.207453</td>
#       <td>0.193171</td>
#       <td>0.060217</td>
#       <td>01:25</td>
#     </tr>
#   </tbody>
# </table>
